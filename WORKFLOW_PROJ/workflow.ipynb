# %% [markdown]
# ## WORKFLOW I NAJLEPSZE PRAKTYKI TWORZENIA PROJEKTU
# <span style="color: orange; font-size: 24px;">INSTALACJA UV, GIT, VS CODE ... SĄ JUŻ WYKONANE</span>
# 1. Zakładasz projekt w VS Code lub Cursor AI
# 2. Podstawa projektu do kodowania
#     a. Zakładanie projektu lokalnie:
#
#    TUTAJ -> [UV](/UV/komendy.ipynb) link do komed i wyjaśnień dotyczących UV
#
#     >`uv init`
#
#     >`uv .venv`
#
#     >`uv add ipykernel`
#
#     > ``
# 3. Katalog `.gitignore`:
# 4. Za
#     b. Zakładanie projektu do GitHuba
#
#     > `git init`
#
#     > `git remote add origin <URL>`
#
#     > `git commit -m "nazwa_zmiany"`
#
#     > `git add .`
#
#     > `git push`
#
#
#
# [def]: s

# %%
<span style="color: orange; font-size: 10px;"></span>
