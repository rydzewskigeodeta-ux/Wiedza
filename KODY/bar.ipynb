# %%
import time
from tqdm import tqdm

spams = ["spam"] * 1000

for spam in tqdm(spams):
    time.sleep(0.01)
# Out:
# Nie można uruchomić jądra, ponieważ środowisko języka Python „.venv-1 (3.15.0) (Python 3.15.0)” nie jest już dostępne. Rozważ wybranie innego jądra lub odświeżenie listy środowisk języka Python.

# %%
import os

os.system("uv pip freeze > requirements.txt")  #uruchamia komędę w terminalu
