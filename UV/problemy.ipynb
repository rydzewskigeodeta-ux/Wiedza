# %% [markdown]
# <h2 style="color:red">ROZWIĄZANIA DO KERNEL - JĄDRA DEBUGERA</h2>
#
# ### LINK do (strony Eda Donera -> FAQ) [ https://edwarddonner.com/faq/] może dać odpowiedź na te pytnia

# %% [markdown]
# Narazie nie mam rozwiązania :(

# %% [markdown]
# /---

# %% [markdown]
# Narazie usunąć ```.venv/...``` zamknąć pomnownie otworyzć ##Testować dotyczy CURSOR`a
