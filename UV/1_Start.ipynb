# %% [markdown]
# # **UV TWORZENIE PROJEKTU**
#
#
# ### ***PODSTAWOWY***
# <h2 style="color:red">WERSJA DLA VS CODE i CURSOR AI
#
# DO SPRAWDZENIA</h2>
#
# |***Co robi***| ***Komenda***|
# |------|-----|
# |założenie projektu| *uv init [nazwa_projektu]*|
# |Tworzy środowisko w .venv/ (izolowany Python dla projektu)|*uv venv*|
# |Instaluje kernel Jupyter w środowisku|*uv add ipykernel*|
# |Instalacja Jupyter Notebook (jeśli chcesz odpalać lokalnie)|*uv pip install notebook*|
# |synchronizuje .venv z pyproject.toml|*uv sync*|
# |instaluje i zapisuje w pyproject.toml bibliotekę OpenAI|*uv add openai*|
#
# <span style="color:green">### **UWAGA**
# **uv pip install -r requirements.txt  ->   instaluje wszystkie biblioteki z pliku** </span>
#
#
# <span style="color:orange">***SPRAWDZAĆ POPRAWIAĆ***</span>

# %% [markdown]
# ### KODOWANIE

# %%
print("Hello, World!")
suma = 0
for i in range(5):
    print(f"Iteracja {i}")
    suma += i
    print(suma)
import os


print(os.getcwd())
print(os.listdir())

a=[]
a = dir(os)
for i in a:
    print(i)
