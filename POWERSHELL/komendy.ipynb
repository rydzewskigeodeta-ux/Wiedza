# %% [markdown]
# ## Komendy do POWERSHELL
# <span style="color:red"> OPRACOWAĆ</span>
#
# |Komenda|Co robi|Tip/szczegóły|
# |------------------------|---|----|
# |`ls` |pokazuje co znajduje się w katalogu|
# |`mkdir [nazwa_katalogu]` |tworzenie katalogu o nazwie [nazwa_katalogu]|
# |`cd [nazwa_katalogu]`|przechodzi do katalogu o nazwie [nazwa_katalogu]|
# |`cd..`|wchodzi o katalog wyżej|
# |`type nul > [nazwa_pliku.X]`| tworzenie pustego pliku o nazwie [nazwa_pliku] i rozszerzeniu [X] | ja robię (type nul > 1.ipynb)
#
#
# ### DO OPRACOWANIA
#
# |Komenda|Angielski zwrot|Co robi|Tip/szczegóły|
# |------------------------|---------|----------|-------|
# |ls|List directory|wyświetla listę katalogów i plików w bieżącym katalogu|
# |pwd|Print current dir|pokazuje aktualną ścieżkę  |
# |cd [folder]|Change dir|przechodzi do folderu [folder] |
# |cd ..|Go up|przejdź do katalogu wyżej  |
# |ls -a|Show hidden files|.... nie działa?|
# |mkdir|Create dir|tworzy katalog  |
# |rm [nazwa pliku]|Delete file|usuwa plik  |
# |rm -r [nazwa katalogu]|Delete folder|usuwa katalog  |
# |cp [plik/katalog ... ścieżka] [plik/katalog … ścieżka]|Copy|kopiuje plik lub katalog z pierwszej nazwy do drugiej  |
# |mv [stara ścieżka] [nowa ścieżka]|Move/rename|zmienia nazwę katalogu lub pliku z old na new  |
# |cat [nazwa pliku]|Read file|wyświetla zawartość pliku  |

# %%
import os

os.system("cd..")
# Out:
# 0
