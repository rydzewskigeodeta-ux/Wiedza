# %% [markdown]
#  <h3 style="color: blueviolet;">TEORIA</h3>
#
#  > Gałąź `branch` tworzysz gdzy robisz część projektu jakąś odnogę. Główna gałąź `main` lub `master`jest jak pień drzewa, która będzie później efektem końcowym projektu. Czyli z gałęźi kolejnych małych części projektu tworzymy nasz cały projekt z którego powstaje program pień. W gałęzi pracujemy nad np. poprawianiem błędów, logowaniem do systemu ...
#
#  > Zachowywanie zmian `commit` zapis zmiany (checkpoint)
#
#
# ---
#
# 👉 commit = zapis
#
# 👉 branch = ścieżka pracy

# %%
<span style="color: rgb(226, 43, 104);">

# %% [markdown]
# ## <span style="color:green">___KOMENDY DO GIT-a___ </span>
#
# |Komendy|Co robi|TIP/szczegóły|
# |-----------------------------------|-----------------------------------------------|---|
# |```git init```                     |inicjalizuje repo lokalne na komputerze        ||
# |```git remote add origin <URL>```  |podpina repo z GitHuba                         |```<URL>``` - skopiuj z githuba po założeniu repo|
# |```git commit -m "init"```         |zapisuje pierwszy stan projektu nazwa="init"   |"init" oznacza nazwę zmiany opisuje co zrobiłeś|
# |```git add .```                    |dodaje wszystkie zmniany do zapisu             |```.``` oznacza że wszystkie jeżeli dodasz ```nazwa_pliku.txt``` dotyczy tylko pliku|
# |```git push```                     |wysyła projekt na _Githuba_                    ||
# |```git branch```                   |pokazuje jaka jest gałąź                       |domyśnie gałęzią jest <span style="color:green">*master*</span>|
# |```git diff```                     |pokazuje wszystko co zmieniłeś w plikach np. kod||
# |```git log```                      |pokazuje historie zmian||
# |```git fletch```                   |sprawdza zmiany, ale ich nie wprowadza||
# |```git status```                   |pokazuje pliki które uległy zmianie||
#
# ---
# 🔹 Podstawowe
# | Komenda         | Opis          | Tip                  |
# | ---------------------- | ----------------------------------- | ------------------------ |
# | `git init`      | start repo    | tylko raz            |
# | `git clone URL` | pobiera repo  | zamiast init         |
# | `git status`    | stan repo     | używaj często        |
# | `git add .`     | dodaje zmiany | ostrożnie (wszystko) |
# | `git commit -m` | zapis zmian   | opisuj dobrze        |
#
# 🔹 Gałęzie
# | Komenda                | Opis            | Tip                 |
# | ---------------------- | ----------------------------------- | ------------------------ |
# | `git branch`           | wyświetla liste gałęzi                         |                     |
# | `git branch name`      | tworzy gałąź ->`name` nazwa gałęzi    |                     |
# | `git checkout name`    | zmiana gałęzi ->`name` nazwa gałęzi   |                     |
# | `git checkout -b name` | tworzy i przełącza do tej gałęzi ->`name` nazwa gałęzi | najczęściej używane |
# | `git branch -d name`   | usuwa gałąź `name` nazwa gałęzi     | po merge            |
#
# 🔹 Synchronizacja
#
# | Komenda                     | Opis                 | Tip             |
# | ---------------------- | ----------------------------------- | ------------------------ |
# | `git remote add origin URL` | link do GitHub       |                 |
# | `git push`                  | wysyła zmiany        |                 |
# | `git pull`                  | pobiera zmiany       | przed pracą     |
# | `git fetch`                 | pobiera bez łączenia | bezpieczniejsze |
#
#
# 🔹 Debug / kontrola
#
# | Komenda             | Opis              | Tip                       |
# | ---------------------- | ----------------------------------- | ------------------------ |
# | `git log`           | historia commitów |                           |
# | `git log --oneline` | skrócona historia |                           |
# | `git diff`          | pokazuje zmiany w plikach  |                           |
# | `git stash`         | zapis tymczasowy  | gdy nie chcesz commitować |
#
# 🔹 Zaawansowane (ważne)
#
# | Komenda      | Opis                    | Tip                |
# | ---------------------- | ----------------------------------- | ------------------------ |
# | `git merge`  | łączy gałęzie           |                    |
# | `git rebase` | przepina historię       | dla zaawansowanych |
# | `git reset`  | cofa zmiany             | ostrożnie          |
# | `git revert` | cofa commit bezpiecznie | preferowane        |

# %% [markdown]
# ### ___Biblioteka do GitHuba___
#
# można używać ```os.system()``` ale brak kontroli nad błędami
#
# ##### __Lepszym rozwiązaniem jest biblioteka ```GitPython```__
#
# inastalacja biblioteki:
#  ```uv add gitpython```

# %%
from git import Repo


#poszukać funkcji -> konend do tej biblioteki
